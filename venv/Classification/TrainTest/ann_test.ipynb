# %%
from tensorflow import keras
from keras import layers
from keras.constraints import maxnorm
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation,  Flatten, Input

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import time

# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# use seaborn plotting defaults
import seaborn as sns; sns.set()

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../../FeatureEngineering/MetaData/data6_&_odds.csv')
df.dropna(inplace=True)

# %%
train_data = df.loc[(df.season <= 2013) & (df.season >= 2007)]
valid_data = df.loc[(df.season > 2013) & (df.season < 2016)]
test_data = df.loc[df.season >= 2016]
full_train_data = pd.concat([train_data, valid_data], axis=0)

X, y = train_data.drop(columns=['home_team_wins']), train_data.home_team_wins
valid_X, valid_y = valid_data.drop(columns=['home_team_wins']), valid_data.home_team_wins
test_X, test_y = test_data.drop(columns=['home_team_wins']), test_data.home_team_wins

# Split our data
X_train, y_train = train_data.drop(columns=["game_date_est","season","game_id","home_team","visitor_team","home_team_id","visitor_team_id","home_team_wins","conference","conference_visitor"]), train_data.home_team_wins
X_val, y_val = valid_data.drop(columns=["game_date_est","season","game_id","home_team","visitor_team","home_team_id","visitor_team_id","home_team_wins","conference","conference_visitor"]), valid_data.home_team_wins
X_test, y_test = test_data.drop(columns=["game_date_est","season","game_id","home_team","visitor_team","home_team_id","visitor_team_id","home_team_wins","conference","conference_visitor"]), test_data.home_team_wins

# %% [markdown]
# #### SFS Forward Dataset

# %%
X_train_for_sfs = train_data[['num_possible_outcomes', 'odds_home', 'odds_away', 'HOME_RECORD_home',
                    'W_PCT_away', 'W_PCT_prev_home', 'ROAD_RECORD_prev_home', 'W_PCT_prev_away',
                    'HOME_RECORD_prev_away', 'ROAD_RECORD_prev_away', 'WIN_PRCT_home_3g',
                    'FT_PCT_home_3g', 'FT_PCT_away_3g', 'FG3_PCT_away_3g', 'WIN_PRCT_home_7g',
                    'FT_PCT_away_7g', 'REB_away_7g', 'diff_avg_ast_home', 'diff_avg_ast_away',
                    'diff_avg_fg3_pct_home', 'diff_avg_fg_pct_away', 'diff_avg_reb_away',
                    'top_players', 'eff', 'eff_visitor', 'G_7days', 'back2back',
                    'HG_7days_VISITOR', 'AG_7days_VISITOR', 'G_7days_VISITOR',
                    'back2back_visitor', 'missing_players', 'missing_players_visitor',
                    'home_elo', 'elo_diff', 'missing_player_diff', 'eff_diff',
                    'Home_Last_5_Avg_FG3_PCT_home', 'Home_Last_5_Avg_FG3_PCT_away',
                    'Away_Last_5_Avg_FG3_PCT_home', 'Away_Last_5_Avg_FT_PCT_away',
                    'diff_fg_pct_last_3_games', 'diff_fg3_pct_last_7_games',
                    'diff_ft_pct_last_3_games', 'diff_ast_last_3_games',
                    'diff_ast_last_7_games', 'diff_win_pct_prev_season',
                    'diff_home_record_last_season', 'diff_road_record_last_season',
                    'diff_curr_win_pct']]

y_train_for_sfs = y_train

X_val_for_sfs = valid_data[['num_possible_outcomes', 'odds_home', 'odds_away', 'HOME_RECORD_home',
                    'W_PCT_away', 'W_PCT_prev_home', 'ROAD_RECORD_prev_home', 'W_PCT_prev_away',
                    'HOME_RECORD_prev_away', 'ROAD_RECORD_prev_away', 'WIN_PRCT_home_3g',
                    'FT_PCT_home_3g', 'FT_PCT_away_3g', 'FG3_PCT_away_3g', 'WIN_PRCT_home_7g',
                    'FT_PCT_away_7g', 'REB_away_7g', 'diff_avg_ast_home', 'diff_avg_ast_away',
                    'diff_avg_fg3_pct_home', 'diff_avg_fg_pct_away', 'diff_avg_reb_away',
                    'top_players', 'eff', 'eff_visitor', 'G_7days', 'back2back',
                    'HG_7days_VISITOR', 'AG_7days_VISITOR', 'G_7days_VISITOR',
                    'back2back_visitor', 'missing_players', 'missing_players_visitor',
                    'home_elo', 'elo_diff', 'missing_player_diff', 'eff_diff',
                    'Home_Last_5_Avg_FG3_PCT_home', 'Home_Last_5_Avg_FG3_PCT_away',
                    'Away_Last_5_Avg_FG3_PCT_home', 'Away_Last_5_Avg_FT_PCT_away',
                    'diff_fg_pct_last_3_games', 'diff_fg3_pct_last_7_games',
                    'diff_ft_pct_last_3_games', 'diff_ast_last_3_games',
                    'diff_ast_last_7_games', 'diff_win_pct_prev_season',
                    'diff_home_record_last_season', 'diff_road_record_last_season',
                    'diff_curr_win_pct']]

y_val_for_sfs = y_val

X_test_for_sfs = test_data[['num_possible_outcomes', 'odds_home', 'odds_away', 'HOME_RECORD_home',
                    'W_PCT_away', 'W_PCT_prev_home', 'ROAD_RECORD_prev_home', 'W_PCT_prev_away',
                    'HOME_RECORD_prev_away', 'ROAD_RECORD_prev_away', 'WIN_PRCT_home_3g',
                    'FT_PCT_home_3g', 'FT_PCT_away_3g', 'FG3_PCT_away_3g', 'WIN_PRCT_home_7g',
                    'FT_PCT_away_7g', 'REB_away_7g', 'diff_avg_ast_home', 'diff_avg_ast_away',
                    'diff_avg_fg3_pct_home', 'diff_avg_fg_pct_away', 'diff_avg_reb_away',
                    'top_players', 'eff', 'eff_visitor', 'G_7days', 'back2back',
                    'HG_7days_VISITOR', 'AG_7days_VISITOR', 'G_7days_VISITOR',
                    'back2back_visitor', 'missing_players', 'missing_players_visitor',
                    'home_elo', 'elo_diff', 'missing_player_diff', 'eff_diff',
                    'Home_Last_5_Avg_FG3_PCT_home', 'Home_Last_5_Avg_FG3_PCT_away',
                    'Away_Last_5_Avg_FG3_PCT_home', 'Away_Last_5_Avg_FT_PCT_away',
                    'diff_fg_pct_last_3_games', 'diff_fg3_pct_last_7_games',
                    'diff_ft_pct_last_3_games', 'diff_ast_last_3_games',
                    'diff_ast_last_7_games', 'diff_win_pct_prev_season',
                    'diff_home_record_last_season', 'diff_road_record_last_season',
                    'diff_curr_win_pct']]

y_test_for_sfs = y_test

# %%
# define the keras model
model = Sequential()
model.add(Dense(10, activation='tanh'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train_for_sfs, y_train_for_sfs, epochs=100, batch_size=32)
# evaluate the keras model
_, accuracy = model.evaluate(X_train_for_sfs, y_train_for_sfs)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.7028 - accuracy: 0.5635
# Epoch 2/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6614 - accuracy: 0.5970
# Epoch 3/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6361 - accuracy: 0.6509
# Epoch 4/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.6601
# Epoch 5/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6218 - accuracy: 0.6577
# Epoch 6/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6169 - accuracy: 0.6465
# Epoch 7/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6100 - accuracy: 0.6461
# Epoch 8/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6166 - accuracy: 0.6581
# Epoch 9/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.6117 - accuracy: 0.6397
# Epoch 10/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6099 - accuracy: 0.6381
# Epoch 11/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6086 - accuracy: 0.6457
# Epoch 12/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6074 - accuracy: 0.6581
# Epoch 13/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6099 - accuracy: 0.6612
# Epoch 14/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.6085 - accuracy: 0.6667
# Epoch 15/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6090 - accuracy: 0.6586
# Epoch 16/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6213 - accuracy: 0.5972
# Epoch 17/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6105 - accuracy: 0.6539
# Epoch 18/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6089 - accuracy: 0.6664
# Epoch 19/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6070 - accuracy: 0.6671
# Epoch 20/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6059 - accuracy: 0.6691
# Epoch 21/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.6074 - accuracy: 0.6749
# Epoch 22/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6052 - accuracy: 0.6701
# Epoch 23/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.6730
# Epoch 24/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6030 - accuracy: 0.6720
# Epoch 25/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6065 - accuracy: 0.6726
# Epoch 26/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6034 - accuracy: 0.6752
# Epoch 27/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6048 - accuracy: 0.6658
# Epoch 28/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6055 - accuracy: 0.6696
# Epoch 29/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 0.6588
# Epoch 30/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6083 - accuracy: 0.6749
# Epoch 31/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6018 - accuracy: 0.6799
# Epoch 32/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6019 - accuracy: 0.6759
# Epoch 33/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.6775
# Epoch 34/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6050 - accuracy: 0.6641
# Epoch 35/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6047 - accuracy: 0.6588
# Epoch 36/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6049 - accuracy: 0.6500
# Epoch 37/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6038 - accuracy: 0.6733
# Epoch 38/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6061 - accuracy: 0.6749
# Epoch 39/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5998 - accuracy: 0.6813
# Epoch 40/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6023 - accuracy: 0.6807
# Epoch 41/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6028 - accuracy: 0.6788
# Epoch 42/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6071 - accuracy: 0.6678
# Epoch 43/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6044 - accuracy: 0.6707
# Epoch 44/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.6775
# Epoch 45/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6029 - accuracy: 0.6759
# Epoch 46/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6084 - accuracy: 0.6799
# Epoch 47/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6091 - accuracy: 0.6819
# Epoch 48/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6053 - accuracy: 0.6783
# Epoch 49/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6036 - accuracy: 0.6772
# Epoch 50/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6025 - accuracy: 0.6780
# Epoch 51/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6021 - accuracy: 0.6764
# Epoch 52/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6023 - accuracy: 0.6709
# Epoch 53/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6030 - accuracy: 0.6710
# Epoch 54/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5994 - accuracy: 0.6800
# Epoch 55/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6039 - accuracy: 0.6820
# Epoch 56/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6093 - accuracy: 0.6829
# Epoch 57/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6071 - accuracy: 0.6706
# Epoch 58/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5985 - accuracy: 0.6830
# Epoch 59/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5996 - accuracy: 0.6809
# Epoch 60/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5996 - accuracy: 0.6841
# Epoch 61/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5997 - accuracy: 0.6822
# Epoch 62/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5997 - accuracy: 0.6819
# Epoch 63/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6028 - accuracy: 0.6826
# Epoch 64/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6009 - accuracy: 0.6829
# Epoch 65/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6064 - accuracy: 0.6768
# Epoch 66/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6030 - accuracy: 0.6768
# Epoch 67/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.6800
# Epoch 68/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6020 - accuracy: 0.6745
# Epoch 69/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6002 - accuracy: 0.6710
# Epoch 70/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5999 - accuracy: 0.6665
# Epoch 71/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6028 - accuracy: 0.6620
# Epoch 72/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6019 - accuracy: 0.6571
# Epoch 73/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5998 - accuracy: 0.6745
# Epoch 74/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.6736
# Epoch 75/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5991 - accuracy: 0.6829
# Epoch 76/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5985 - accuracy: 0.6812
# Epoch 77/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5986 - accuracy: 0.6726
# Epoch 78/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5998 - accuracy: 0.6681
# Epoch 79/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.6445
# Epoch 80/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.6522
# Epoch 81/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6016 - accuracy: 0.6674
# Epoch 82/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5989 - accuracy: 0.6794
# Epoch 83/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6045 - accuracy: 0.6823
# Epoch 84/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6013 - accuracy: 0.6828
# Epoch 85/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6013 - accuracy: 0.6806
# Epoch 86/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5994 - accuracy: 0.6833
# Epoch 87/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5996 - accuracy: 0.6814
# Epoch 88/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.6826
# Epoch 89/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.6803
# Epoch 90/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5979 - accuracy: 0.6813
# Epoch 91/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.6841
# Epoch 92/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6000 - accuracy: 0.6807
# Epoch 93/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.6758
# Epoch 94/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6014 - accuracy: 0.6767
# Epoch 95/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6002 - accuracy: 0.6788
# Epoch 96/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5990 - accuracy: 0.6788
# Epoch 97/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6054 - accuracy: 0.6778
# Epoch 98/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6009 - accuracy: 0.6690
# Epoch 99/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6008 - accuracy: 0.6623
# Epoch 100/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5991 - accuracy: 0.6722
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5990 - accuracy: 0.6783
# Accuracy: 67.83

# %%
start_time = time.time()
# val_score = model.score(X_val, y_val)

preds = model.predict(X_test_for_sfs)
preds = (preds > 0.7)

# test_score = model.score(X_val, y_val)
# Out:
# 144/144 [==============================] - 0s 2ms/step

# %%
target_names = ['home_loss', 'home_win']

print("Συνολικός χρόνος fit και predict: %s seconds" % (time.time() - start_time))
print(classification_report(y_test_for_sfs, preds, target_names=target_names))
# Out:
# Συνολικός χρόνος fit και predict: 1.3914802074432373 seconds
#               precision    recall  f1-score   support
#
#    home_loss       0.52      0.82      0.64      1935
#     home_win       0.77      0.45      0.57      2648
#
#     accuracy                           0.60      4583
#    macro avg       0.65      0.63      0.60      4583
# weighted avg       0.66      0.60      0.60      4583

# %%
X_train_back_sfs = train_data[['num_possible_outcomes', 'odds_home', 'odds_away', 'HOME_RECORD_home',
                     'W_PCT_away', 'W_PCT_prev_away', 'HOME_RECORD_prev_away',
                     'ROAD_RECORD_prev_away', 'FT_PCT_home_3g', 'FG3_PCT_home_3g', 'PTS_away_3g',
                     'FG_PCT_away_3g', 'FT_PCT_away_3g', 'FG3_PCT_away_3g', 'PTS_home_7g',
                     'FG_PCT_home_7g', 'AST_home_7g', 'AST_away_7g', 'REB_away_7g',
                     'diff_avg_pts_away', 'diff_avg_ast_home', 'diff_avg_ast_away',
                     'diff_avg_fg3_pct_home', 'top_players', 'top_players_visitor', 'eff_visitor',
                     'G_7days', 'back2back', 'HG_7days_VISITOR', 'AG_7days_VISITOR',
                     'G_7days_VISITOR', 'back2back_visitor', 'home_elo', 'elo_diff',
                     'missing_player_diff', 'eff_diff', 'Home_Last_5_Avg_AST_home',
                     'Home_Last_5_Avg_REB_home', 'Home_Last_5_Avg_REB_away',
                     'Home_Last_5_Avg_FG3_PCT_away', 'Away_Last_5_Avg_PTS_home',
                     'Away_Last_5_Avg_FG3_PCT_home', 'Away_Last_5_Avg_AST_home',
                     'Away_Last_5_Avg_FT_PCT_away', 'diff_fg3_pct_last_3_games',
                     'diff_fg3_pct_last_7_games', 'diff_ft_pct_last_3_games',
                     'diff_ast_last_7_games', 'diff_reb_last_3_games',
                     'diff_win_pct_3_last_games']]

y_train_back_sfs = y_train

X_val_back_sfs = valid_data[['num_possible_outcomes', 'odds_home', 'odds_away', 'HOME_RECORD_home',
                     'W_PCT_away', 'W_PCT_prev_away', 'HOME_RECORD_prev_away',
                     'ROAD_RECORD_prev_away', 'FT_PCT_home_3g', 'FG3_PCT_home_3g', 'PTS_away_3g',
                     'FG_PCT_away_3g', 'FT_PCT_away_3g', 'FG3_PCT_away_3g', 'PTS_home_7g',
                     'FG_PCT_home_7g', 'AST_home_7g', 'AST_away_7g', 'REB_away_7g',
                     'diff_avg_pts_away', 'diff_avg_ast_home', 'diff_avg_ast_away',
                     'diff_avg_fg3_pct_home', 'top_players', 'top_players_visitor', 'eff_visitor',
                     'G_7days', 'back2back', 'HG_7days_VISITOR', 'AG_7days_VISITOR',
                     'G_7days_VISITOR', 'back2back_visitor', 'home_elo', 'elo_diff',
                     'missing_player_diff', 'eff_diff', 'Home_Last_5_Avg_AST_home',
                     'Home_Last_5_Avg_REB_home', 'Home_Last_5_Avg_REB_away',
                     'Home_Last_5_Avg_FG3_PCT_away', 'Away_Last_5_Avg_PTS_home',
                     'Away_Last_5_Avg_FG3_PCT_home', 'Away_Last_5_Avg_AST_home',
                     'Away_Last_5_Avg_FT_PCT_away', 'diff_fg3_pct_last_3_games',
                     'diff_fg3_pct_last_7_games', 'diff_ft_pct_last_3_games',
                     'diff_ast_last_7_games', 'diff_reb_last_3_games',
                     'diff_win_pct_3_last_games']]

y_val_back_sfs = y_val

X_test_back_sfs = test_data[['num_possible_outcomes', 'odds_home', 'odds_away', 'HOME_RECORD_home',
                     'W_PCT_away', 'W_PCT_prev_away', 'HOME_RECORD_prev_away',
                     'ROAD_RECORD_prev_away', 'FT_PCT_home_3g', 'FG3_PCT_home_3g', 'PTS_away_3g',
                     'FG_PCT_away_3g', 'FT_PCT_away_3g', 'FG3_PCT_away_3g', 'PTS_home_7g',
                     'FG_PCT_home_7g', 'AST_home_7g', 'AST_away_7g', 'REB_away_7g',
                     'diff_avg_pts_away', 'diff_avg_ast_home', 'diff_avg_ast_away',
                     'diff_avg_fg3_pct_home', 'top_players', 'top_players_visitor', 'eff_visitor',
                     'G_7days', 'back2back', 'HG_7days_VISITOR', 'AG_7days_VISITOR',
                     'G_7days_VISITOR', 'back2back_visitor', 'home_elo', 'elo_diff',
                     'missing_player_diff', 'eff_diff', 'Home_Last_5_Avg_AST_home',
                     'Home_Last_5_Avg_REB_home', 'Home_Last_5_Avg_REB_away',
                     'Home_Last_5_Avg_FG3_PCT_away', 'Away_Last_5_Avg_PTS_home',
                     'Away_Last_5_Avg_FG3_PCT_home', 'Away_Last_5_Avg_AST_home',
                     'Away_Last_5_Avg_FT_PCT_away', 'diff_fg3_pct_last_3_games',
                     'diff_fg3_pct_last_7_games', 'diff_ft_pct_last_3_games',
                     'diff_ast_last_7_games', 'diff_reb_last_3_games',
                     'diff_win_pct_3_last_games']]

y_test_back_sfs = y_test

# %%
# define the keras model
model = Sequential()
model.add(Dense(10, activation='tanh'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train_back_sfs, y_train_back_sfs, epochs=100, batch_size=32)
# evaluate the keras model
_, accuracy = model.evaluate(X_train_back_sfs, y_train_back_sfs)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 216/216 [==============================] - 2s 3ms/step - loss: 0.6821 - accuracy: 0.5700
# Epoch 2/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.6366 - accuracy: 0.5996
# Epoch 3/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.6154 - accuracy: 0.6626
# Epoch 4/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6090 - accuracy: 0.6678
# Epoch 5/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6034 - accuracy: 0.6786
# Epoch 6/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6044 - accuracy: 0.6739
# Epoch 7/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.6041 - accuracy: 0.6655
# Epoch 8/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6037 - accuracy: 0.6807
# Epoch 9/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6051 - accuracy: 0.6780
# Epoch 10/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6038 - accuracy: 0.6630
# Epoch 11/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6077 - accuracy: 0.6529
# Epoch 12/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.6758
# Epoch 13/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6029 - accuracy: 0.6772
# Epoch 14/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5991 - accuracy: 0.6701
# Epoch 15/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.6616
# Epoch 16/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.6623
# Epoch 17/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5998 - accuracy: 0.6783
# Epoch 18/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5969 - accuracy: 0.6839
# Epoch 19/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.6796
# Epoch 20/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5994 - accuracy: 0.6787
# Epoch 21/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5997 - accuracy: 0.6855
# Epoch 22/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5963 - accuracy: 0.6842
# Epoch 23/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5997 - accuracy: 0.6774
# Epoch 24/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5980 - accuracy: 0.6790
# Epoch 25/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5967 - accuracy: 0.6732
# Epoch 26/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5993 - accuracy: 0.6646
# Epoch 27/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.6710
# Epoch 28/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5967 - accuracy: 0.6825
# Epoch 29/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.6812
# Epoch 30/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.6778
# Epoch 31/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.6764
# Epoch 32/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5963 - accuracy: 0.6817
# Epoch 33/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6004 - accuracy: 0.6774
# Epoch 34/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6059 - accuracy: 0.6777
# Epoch 35/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6046 - accuracy: 0.6739
# Epoch 36/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6075 - accuracy: 0.6761
# Epoch 37/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6032 - accuracy: 0.6699
# Epoch 38/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6043 - accuracy: 0.6717
# Epoch 39/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6034 - accuracy: 0.6677
# Epoch 40/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6017 - accuracy: 0.6768
# Epoch 41/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.6794
# Epoch 42/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.6006 - accuracy: 0.6748
# Epoch 43/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.6029 - accuracy: 0.6739
# Epoch 44/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.6049 - accuracy: 0.6767
# Epoch 45/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.6008 - accuracy: 0.6804
# Epoch 46/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5993 - accuracy: 0.6801
# Epoch 47/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5999 - accuracy: 0.6797
# Epoch 48/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6021 - accuracy: 0.6814
# Epoch 49/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6068 - accuracy: 0.6752
# Epoch 50/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6039 - accuracy: 0.6706
# Epoch 51/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6047 - accuracy: 0.6725
# Epoch 52/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.6617
# Epoch 53/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5983 - accuracy: 0.6571
# Epoch 54/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5976 - accuracy: 0.6629
# Epoch 55/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5956 - accuracy: 0.6571
# Epoch 56/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5965 - accuracy: 0.6716
# Epoch 57/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.6706
# Epoch 58/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.6810
# Epoch 59/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.6770
# Epoch 60/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5953 - accuracy: 0.6754
# Epoch 61/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5980 - accuracy: 0.6638
# Epoch 62/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6033 - accuracy: 0.6586
# Epoch 63/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6017 - accuracy: 0.6648
# Epoch 64/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6023 - accuracy: 0.6743
# Epoch 65/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6052 - accuracy: 0.6775
# Epoch 66/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6021 - accuracy: 0.6780
# Epoch 67/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6021 - accuracy: 0.6819
# Epoch 68/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.6012 - accuracy: 0.6806
# Epoch 69/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5995 - accuracy: 0.6820
# Epoch 70/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5991 - accuracy: 0.6670
# Epoch 71/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.6719
# Epoch 72/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5999 - accuracy: 0.6784
# Epoch 73/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5968 - accuracy: 0.6771
# Epoch 74/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5956 - accuracy: 0.6706
# Epoch 75/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.6616
# Epoch 76/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5989 - accuracy: 0.6642
# Epoch 77/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5998 - accuracy: 0.6812
# Epoch 78/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5977 - accuracy: 0.6786
# Epoch 79/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.6807
# Epoch 80/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5992 - accuracy: 0.6816
# Epoch 81/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6037 - accuracy: 0.6777
# Epoch 82/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.6002 - accuracy: 0.6804
# Epoch 83/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5952 - accuracy: 0.6735
# Epoch 84/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5960 - accuracy: 0.6649
# Epoch 85/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5971 - accuracy: 0.6799
# Epoch 86/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5995 - accuracy: 0.6806
# Epoch 87/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5981 - accuracy: 0.6861
# Epoch 88/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.6828
# Epoch 89/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5990 - accuracy: 0.6822
# Epoch 90/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5972 - accuracy: 0.6764
# Epoch 91/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5962 - accuracy: 0.6641
# Epoch 92/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5963 - accuracy: 0.6803
# Epoch 93/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5956 - accuracy: 0.6855
# Epoch 94/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5945 - accuracy: 0.6861
# Epoch 95/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5977 - accuracy: 0.6814
# Epoch 96/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5961 - accuracy: 0.6786
# Epoch 97/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5980 - accuracy: 0.6800
# Epoch 98/100
# 216/216 [==============================] - 0s 2ms/step - loss: 0.5954 - accuracy: 0.6794
# Epoch 99/100
# 216/216 [==============================] - 1s 2ms/step - loss: 0.5972 - accuracy: 0.6817
# Epoch 100/100
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5980 - accuracy: 0.6830
# 216/216 [==============================] - 1s 3ms/step - loss: 0.5965 - accuracy: 0.6803
# Accuracy: 68.03

# %%
start_time = time.time()
# val_score = model.score(X_val, y_val)

preds = model.predict(X_test_back_sfs)
preds = (preds > 0.5)

# test_score = model.score(X_val, y_val)
# Out:
# 144/144 [==============================] - 0s 2ms/step

# %%
target_names = ['home_loss', 'home_win']

print("Συνολικός χρόνος fit και predict: %s seconds" % (time.time() - start_time))
print(classification_report(y_test_back_sfs, preds, target_names=target_names))
# Out:
# Συνολικός χρόνος fit και predict: 1.0578587055206299 seconds
#               precision    recall  f1-score   support
#
#    home_loss       0.66      0.41      0.50      1935
#     home_win       0.66      0.85      0.74      2648
#
#     accuracy                           0.66      4583
#    macro avg       0.66      0.63      0.62      4583
# weighted avg       0.66      0.66      0.64      4583
